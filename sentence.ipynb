# %% [markdown]
# <a href="https://colab.research.google.com/github/arpit-devop/predictive-analysis-sentence-assignment/blob/main/sentence.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ===============================
# Install Required Libraries
# ===============================
# !pip install transformers sentence-transformers torch pandas numpy scikit-learn matplotlib

# ===============================
# Imports
# ===============================
import time
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sentence_transformers import SentenceTransformer, util
from sklearn.metrics import mean_squared_error

# ===============================
# Model Definitions
# ===============================
models = {
    "all-MiniLM-L6-v2": "sentence-transformers/all-MiniLM-L6-v2",
    "all-mpnet-base-v2": "sentence-transformers/all-mpnet-base-v2",
    "paraphrase-MiniLM-L12-v2": "sentence-transformers/paraphrase-MiniLM-L12-v2",
    "paraphrase-mpnet-base-v2": "sentence-transformers/paraphrase-mpnet-base-v2"
}

# ===============================
# Sentence Pairs & Ground Truth
# ===============================
sentence_pairs = [
    ("The student is preparing for an exam", "A learner is studying for a test"),
    ("The car stopped at the traffic signal", "A vehicle halted at a red light"),
    ("He is reading a book in the library", "A man is watching television at home"),
    ("The chef cooked a delicious meal", "The cook prepared tasty food"),
    ("It is raining heavily today", "The weather is dry and sunny"),
    ("She submitted the assignment on time", "The homework was turned in before the deadline")
]

ground_truth = [0.9, 0.85, 0.2, 0.95, 0.1, 0.9]


# ===============================
# Model Evaluation
# ===============================
results = []

for name, model_id in models.items():
    model = SentenceTransformer(model_id)

    start = time.time()
    preds = []

    for s1, s2 in sentence_pairs:
        emb1 = model.encode(s1, convert_to_tensor=True)
        emb2 = model.encode(s2, convert_to_tensor=True)
        sim = util.cos_sim(emb1, emb2).item()
        preds.append(sim)

    inference_time = (time.time() - start) / len(sentence_pairs)
    accuracy = 1 - mean_squared_error(ground_truth, preds)
    size_mb = sum(p.numel() for p in model.parameters()) * 4 / 1e6
    embedding_dim = model.get_sentence_embedding_dimension()

    results.append([name, accuracy, size_mb, inference_time, embedding_dim])

# ===============================
# Results DataFrame
# ===============================
df = pd.DataFrame(results, columns=[
    "Model", "Accuracy", "Model_Size_MB", "Inference_Time", "Embedding_Dim"
])

print(df)

# ===============================
# TOPSIS Implementation
# ===============================
weights = np.array([0.35, 0.20, 0.20, 0.25])   # Accuracy, Size, Time, Dim
criteria = np.array([1, -1, -1, 1])            # Benefit / Cost

def topsis(matrix, weights, criteria):
    norm = matrix / np.sqrt((matrix**2).sum(axis=0))
    weighted = norm * weights

    ideal_best = np.max(weighted * criteria, axis=0)
    ideal_worst = np.min(weighted * criteria, axis=0)

    dist_best = np.sqrt(((weighted - ideal_best)**2).sum(axis=1))
    dist_worst = np.sqrt(((weighted - ideal_worst)**2).sum(axis=1))

    return dist_worst / (dist_best + dist_worst)

decision_matrix = df.iloc[:, 1:].values
df["TOPSIS_Score"] = topsis(decision_matrix, weights, criteria)

df = df.sort_values("TOPSIS_Score", ascending=False)
print("\nTOPSIS Ranking:")
print(df)

# ===============================
# Visualization
# ===============================
plt.figure()
plt.bar(df["Model"], df["TOPSIS_Score"])
plt.xticks(rotation=30)
plt.xlabel("Models")
plt.ylabel("TOPSIS Score")
plt.title("TOPSIS Ranking of Sentence Similarity Models")
plt.show()

plt.figure()
plt.scatter(df["Inference_Time"], df["Accuracy"])
for i, model in enumerate(df["Model"]):
    plt.text(df["Inference_Time"].iloc[i], df["Accuracy"].iloc[i], model)

plt.xlabel("Inference Time (seconds)")
plt.ylabel("Accuracy")
plt.title("Accuracy vs Inference Time")
plt.show()

# ===============================
# Best Model Demo
# ===============================
best_model = SentenceTransformer("sentence-transformers/paraphrase-MiniLM-L12-v2")

emb1 = best_model.encode("How are you?")
emb2 = best_model.encode("How do you do?")

similarity = util.cos_sim(emb1, emb2)
print("Similarity Score:", similarity.item())
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# ...
